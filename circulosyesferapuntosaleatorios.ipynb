# %%
#---------------------------------------------------------
#---Es para hacer puntos aleatorios en un circulo 
#---
#---------------------------------------------------------
#-----TODAS LAS LIBRERIAS QUE PODRIAN SER DE UTILIDAD-----
import random #proporciona un generador de números aleatorios
import math #Provee acceso a funciones matematicas estandar.
from matplotlib import pyplot as plt #Para visualizaciones y gráficos. Nos va a permitir realizar los gráficos de las distintas distribuciones de datos.
import numpy as np #proporciona algunas funciones estadísticas que podemos aplicar fácilmente sobre los arrays de Numpy.
import seaborn as sns # importando seaborn; Esta librería es un complemento ideal de matplotlib para realizar gráficos estadísticos.
import pandas as pd #librería para análisis de datos y financieros. Posee funciones de estadística descriptiva sobre nuestros datos y


circle_r = 1.0 #radio del circulo
circle_x = 0.0 #coord. x circulo
circle_y = 0.0 #coord. y circulo

# Para calcular las coordenadas de forma aleatoria del circulo
for i in range(0, 2000): #ciclo para generar los puntos, 2000 puntos
    alpha = 2 * math.pi * random.random() # angulos aleatorios
    r = circle_r * math.sqrt(random.random()) # radios aleatorios
    x = r * math.cos(alpha) + circle_x #x aleatorio
    y = r * math.sin(alpha) + circle_y #y aleatorio

    #print(x, y) #imprimir todas las coordenadas del circulo
    plt.plot(x,y,'o',  markersize=2)  # plot data points

# %%
#---------------------------------------------------------
#---Es para hacer puntos aleatorios en un circulo 
#---donde los puntos esten mas 'centrados'
#---------------------------------------------------------
#-----TODAS LAS LIBRERIAS QUE PODRIAN SER DE UTILIDAD-----
import random #proporciona un generador de números aleatorios
import math #Provee acceso a funciones matematicas estandar.
from matplotlib import pyplot as plt #Para visualizaciones y gráficos. Nos va a permitir realizar los gráficos de las distintas distribuciones de datos.
import numpy as np #proporciona algunas funciones estadísticas que podemos aplicar fácilmente sobre los arrays de Numpy.
import seaborn as sns # importando seaborn; Esta librería es un complemento ideal de matplotlib para realizar gráficos estadísticos.
import pandas as pd #librería para análisis de datos y financieros. Posee funciones de estadística descriptiva sobre nuestros datos y



circle_r <= 1.0 #radio del circulo
circle_x = 0.0 #coord. x circulo
circle_y = 0.0 #coord. y circulo



# Para calcular las coordenadas de forma aleatoria del circulo, de r<1
for i in range(0, 2000): #ciclo para generar los puntos, 2000 puntos
    alpha = 2 * math.pi * random.random() # alfa aleatorio
    r = circle_r * math.sqrt(random.random()) # r aleatorio
    x = r*r * math.cos(alpha) + circle_x #coord. x
    y = r*r * math.sin(alpha) + circle_y #coord. y

    #print(x, y) #lista de datos
    plt.plot(x,y,'o', markersize=2)  # grafica de datos

# %%
#---------------------------------------------------------
#---Es para hacer puntos aleatorios en un esfera
#---
#---------------------------------------------------------
#-----TODAS LAS LIBRERIAS QUE PODRIAN SER DE UTILIDAD-----
import random #proporciona un generador de números aleatorios
import math #Provee acceso a funciones matematicas estandar.
from matplotlib import pyplot as plt #Para visualizaciones y gráficos. Nos va a permitir realizar los gráficos de las distintas distribuciones de datos.
import numpy as np #proporciona algunas funciones estadísticas que podemos aplicar fácilmente sobre los arrays de Numpy.
import seaborn as sns # importando seaborn; Esta librería es un complemento ideal de matplotlib para realizar gráficos estadísticos.
import pandas as pd #librería para análisis de datos y financieros. Posee funciones de estadística descriptiva sobre nuestros datos y
from mpl_toolkits.mplot3d import axes3d #permite hacer graficas en 3D, suministrando ejes a nuestro objeto


def sample_spherical(npoints, ndim=3): #definición de funciones
    vec = np.random.randn(ndim, npoints) #funcion
    vec /= np.linalg.norm(vec, axis=0) #
    return vec

#circle_r <= 1.0 #radio del circulo

for i in range(0, 2000): #ciclo para puntos en la esfera
    theta = 2 * math.pi * random.random() # angulo theta aleatorio
    phi= math.pi * random.random() # angulo phi aleatorio
    r = circle_r * math.sqrt(random.random()) # circulo aleatorio
    x = (np.sin(theta), np.cos(phi)) #coordenada x
    y = (np.sin(theta), np.sin(phi)) #coordenada y
    z = (np.cos(theta), np.ones_like(phi)) #coordenada z

xi, yi, zi = sample_spherical(2000) #puntos esfera

fig, ax = plt.subplots(1, 1, subplot_kw={'projection':'3d', 'aspect':'equal'}) #funcion que nos lleva a hacer la proyeccion en 3D
plt.plot(xi,yi,zi,'o',  markersize=1)  # graficando los puntos
