# %% [markdown]
# # histograma de distancias para 2d y 3d
#
# Referencias principales:
# https://jakevdp.github.io/PythonDataScienceHandbook/04.05-histograms-and-binnings.html
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.histogram.html

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

N = 500 # puntos
t = 20  #tamaño caja
dat = t*np.random.rand(N,2) #"datos"
ale = t*np.random.rand(N,2) #aleatorio

#distancia entre puntos
def  distancia(x1,x2,y1,y2):
    d = np.sqrt((x2 - x1)**2 + (y2-y1)**2) #distancia 2D
    return d

#matriz simetrica
dtot = N*(N-1)/2
j = 0
dold = 0
dmax = 0
disdat = [] #guardar distancias
disale = [] #guardar distancias

for i in range(N):
    for j in range(i+1,N):
        d_d = distancia(dat[i][0],dat[j][0],dat[i][1],dat[j][1])
        d_r = distancia(ale[i][0],ale[j][0],ale[i][1],ale[j][1])
        disdat.append(d_d)
        disale.append(d_r)
        
#graf. datos
plt.plot(dat,'o')
plt.show()
#hist. datos
datn, datbin ,m = plt.hist(disdat,bins=100, color='green')
plt.show()
#hist aleatorio
alen, alebin, n = plt.hist(disale,bins=100, color='yellow' )
plt.show()
#hist 2d datos-aleatorio
plt.hist2d(disdat, disale , bins=100)
cb = plt.colorbar()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import axes3d 

N = 500#Numero de puntos
t = 20#Longutud de la caja



dat = t*np.random.rand(N,3)#Genera un arreglo de  N puntos aleatorios
ale = t*np.random.rand(N,3)




def  distancia(x1,x2,x3,y1,y2,y3):
    d = np.sqrt((x1-y1)**2 + (x2-y1)**2 + (x3-y3)**2) #dist. 3D
    return d

dtot = N*(N-1)/2
j = 0
dold = 0
dmax = 0
disdat = []
disale = []


for i in range(N):
    for j in range(i+1,N):
        for k in range (j+1,N):
            d_d = distancia(dat[i][0],dat[j][0],dat[k][0],dat[i][1],dat[j][1],dat[k][1])
            d_r = distancia(ale[i][0],ale[j][0],ale[k][0],ale[i][1],ale[j][1],ale[k][1])
            disdat.append(d_d)
            disale.append(d_r)
            
        
plt.plot(dat,'o')
plt.show()
        
alen, alebin, m = plt.hist(disale,bins=100)
plt.show()

datn, datbin, p = plt.hist(disdat,bins=100, color='red')
plt.show()

plt.hist2d(disdat, disale , bins=100)
cb = plt.colorbar()
